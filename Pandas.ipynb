# %%
import pandas as pd
df=pd.read_csv('nyc_weather.csv')
df
# df.describe(include='all')
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
print (type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df.loc[df['Temperature']==df.Temperature.max(),['EST','Temperature','Humidity']]
#mention the columns which you want to display
# Out:
#          EST  Temperature  Humidity
# 9  1/10/2016           50        71

# %%
df.loc[df['Humidity']==df.Humidity.min()]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 6  1/7/2016           39        11        33                 30.28
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 6               10           2.0               0           3    NaN
#
#    WindDirDegrees
# 6             293

# %%
df.loc[df['Events']=='Rain',['EST','Events']]
# Out:
#           EST Events
# 8    1/9/2016   Rain
# 9   1/10/2016   Rain
# 15  1/16/2016   Rain
# 26  1/27/2016   Rain

# %%
df.loc[df['Temperature']==df.Temperature.max()][['EST','Humidity']]
# Out:
#          EST  Humidity
# 9  1/10/2016        71

# %%
"""To construct a data frame externally"""
snapseed=[('40%','60%','200px')]
pd.DataFrame=(snapseed,columns=list['Brightness','Ambiance','Pixels'])
# Out:
#   File "<ipython-input-41-c842068cdb5e>", line 3
#     pd.DataFrame=(snapseed,columns=list['Brightness','Ambiance','Pixels'])
#                                   ^
# SyntaxError: invalid syntax

# %%
df.shape #31rows and 11 columns
# Out:
# (31, 11)

# %%
df[2:8]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
# 5  1/6/2016           33         4        35                 30.50
# 6  1/7/2016           39        11        33                 30.28
# 7  1/8/2016           39        29        64                 30.20
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# 5               10           4.0               0           0    NaN
# 6               10           2.0               0           3    NaN
# 7               10           4.0               0           8    NaN
#
# ...

# %%
df.iloc[2:5,3:7]
# Out:
#    Humidity  Sea Level PressureIn  VisibilityMiles  WindSpeedMPH
# 2        47                 29.86               10           8.0
# 3        44                 30.05               10           9.0
# 4        41                 30.57               10           5.0

# %%
d1=pd.read_csv('weather_data.csv')
d1.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
d2=pd.read_excel('weather_data.xlsx')
d2.set_index('day')
#pip install xlrd
d3=d2.loc[d2['temperature']==32][['day']]
d3.to_excel('day.xlsx')
d4=pd.read_excel('day.xlsx')
d4=d2.loc[d2['temperature']==34]
# Out:
#    Unnamed: 0       day
# 0           0  1/1/2017
# 1           4  1/5/2017

# %%
d4=pd.read_excel('day.xlsx')
d5=d2.loc[d2['temperature']%2==0]
d5.to_excel('day.xlsx',sheet_name='even_tempertaure')

# %%
dftemp=pd.read_csv('weather_data_cities.csv')
print (repr(dftemp))
g1=dftemp.groupby('city')
g1
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
for city,city_def in g1:
    print (city)
# Out:
# mumbai
# new york
# paris

# %%
for city,city_f in g1:
    print (city)
    print (city_f)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
gcity=g1.get_group('new york')
print (gcity)
gcity.loc[gcity['temperature']%2==0]
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow

# %%
gcity.max()
# Out:
# day            1/4/2017
# city           new york
# temperature          36
# windspeed            12
# event             Sunny
# dtype: object

# %%
for city,temperature in g1:
    print (city)
    print (temperature.max())
# Out:
# mumbai
# day            1/4/2017
# city             mumbai
# temperature          92
# windspeed            15
# event             Sunny
# dtype: object
# new york
# day            1/4/2017
# city           new york
# temperature          36
# windspeed            12
# event             Sunny
# dtype: object
# paris
# day            1/4/2017
# city              paris
# temperature          54
# windspeed            20
# event             Sunny
# dtype: object

# %%
"""concatenate data frames"""
import numpy as np

# """pd.DataFrame is a class defined by pandas.
# A class is "callable" meaning that you can call it with parentheses like so pd.DataFrame(). 
# However, in Python the = is an assignment operator and
# you did pd.DataFrame = {} which assigned some dictionary to the same spot that the DataFrame class constructor used to be"""


india_weather=pd.DataFrame({'city':['Delhi','Bhopal','Indore','Pune'],
                           'Temperature':[30,20,23,45]
                           })
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-a352824ed606> in <module>
#       4
#       5 india_weather=pd.DataFrame({'city':['Delhi','Bhopal','Indore','Pune'],
# ----> 6                            'Temperature':[30,20,23,45]
#       7                            })
#       8 """pd.DataFrame is a class defined by pandas.
#
# TypeError: 'dict' object is not callable

# %%
pd.DataFrame({'Name':['Ankesh','Harvey','Louis'],})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-23d2e5cec586> in <module>
# ----> 1 pd.DataFrame({'Name':['Ankesh','Harvey','Louis'],})
#
# TypeError: 'dict' object is not callable

# %%
india_weather=pd.DataFrame('city'=['Raipur','Bhilai'])
# Out:
#   File "<ipython-input-146-2c99e1232493>", line 1
#     india_weather=pd.DataFrame('city'=['Raipur','Bhilai'])
#                               ^
# SyntaxError: keyword can't be an expression

# %%
d={'Name':'Ankesh','Age':24,'Company':'Microsoft'}
d
pd.DataFrame(data=d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-880d7f69331b> in <module>
#       1 d={'Name':'Ankesh','Age':24,'Company':'Microsoft'}
#       2 d
# ----> 3 pd.DataFrame(data=d)
#
# TypeError: 'dict' object is not callable

# %%
dftemp
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df_ny=dftemp.loc[dftemp['city']=='new york']
df_ny
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
df_mb=dftemp.loc[dftemp['city']=='mumbai']
df_mb
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
df_conc=pd.concat([df_ny,df_mb],axis=0)
df_conc
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# 4  1/1/2017    mumbai           90          5  Sunny
# 5  1/2/2017    mumbai           85         12    Fog
# 6  1/3/2017    mumbai           87         15    Fog
# 7  1/4/2017    mumbai           92          5   Rain

# %%
df_conc1=pd.concat([df_ny,df_mb],axis=1,ignore_index=False)

df_conc1
# Out:
#         day      city  temperature  windspeed  event       day    city  \
# 0  1/1/2017  new york         32.0        6.0   Rain       NaN     NaN
# 1  1/2/2017  new york         36.0        7.0  Sunny       NaN     NaN
# 2  1/3/2017  new york         28.0       12.0   Snow       NaN     NaN
# 3  1/4/2017  new york         33.0        7.0  Sunny       NaN     NaN
# 4       NaN       NaN          NaN        NaN    NaN  1/1/2017  mumbai
# 5       NaN       NaN          NaN        NaN    NaN  1/2/2017  mumbai
# 6       NaN       NaN          NaN        NaN    NaN  1/3/2017  mumbai
# 7       NaN       NaN          NaN        NaN    NaN  1/4/2017  mumbai
#
#    temperature  windspeed  event
# 0          NaN        NaN    NaN
# 1          NaN        NaN    NaN
# 2          NaN        NaN    NaN
# 3          NaN        NaN    NaN
# 4         90.0        5.0  Sunny
# 5         85.0       12.0    Fog
# 6         87.0       15.0    Fog
# 7         92.0        5.0   Rain

# %%
lst = ['Geeks', 'For', 'Geeks', 'is', 
            'portal', 'for', 'Geeks']
lst
dd=pd.DataFrame(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-49e1a7ff4c53> in <module>
#       2             'portal', 'for', 'Geeks']
#       3 lst
# ----> 4 dd=pd.DataFrame(lst)
#
# TypeError: 'dict' object is not callable
